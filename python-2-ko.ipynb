# %% [markdown]
# # MLV PRASAD
# # PYTHON 2 - KO
# # 10 - 11 AM
# # SESSION STARTS AT 10.05 AM

# %%
# YOU CAN ASK ANY DOUBTS BEFORE 10.05 am

# %%
a = [4 ,8 ,12 ,16]
a[2:6]= [20,24,28] # 2,3,4 
# [4,8,20,24,28]
a
# Out:
# [4, 8, 20, 24, 28]

# %%
a = [4 ,8 ,12 ,16]
print(a[0],a[1],a[2],a[3])
a.append(75)# [4,8,12,16,75]
a[4]  = 55
print(a[4]) # [4,8,12,16,55]
# Out:
# 4 8 12 16
# 55

# %%
a = [1,2,3]
a[0] = "shraddha"
a
# Out:
# ['shraddha', 2, 3]

# %%
#TOPICS 

#1. DATA structures(#list comprehension and 
    --dict comprehension)
# 2. LOOP STATEMENTS
3 FUNCTION
  (return and print)
4. lambda functions

# %% [markdown]
# # list tuple dictionary set

# %%
# for loop

# %%
for i in range(6,10): # [6,7,8,9]
    print(i)
# Out:
# 6
# 7
# 8
# 9

# %%
for i in [6,7]:# [6,7]
    print(i) # 7
    for j in  [ 20, 21] :# [20 21 ]
        print(i,j)#  6 20
    print("abhinav")
    
"""

6
6 20
6 21
abhinav
7
7 20
7 21
abhinav

"""
# Out:
# 6
# 6 20
# 6 21
# abhinav
# 7
# 7 20
# 7 21
# abhinav
# '\n6\n6 20\n6 21\nabhinav\n7\n7 20\n7 21\nabhinav\n\n'

# %%
list(range(6,10))
# Out:
# [6, 7, 8, 9]

# %%
# while loop

a = 10

while a < 15 : # true
    print(a)
    
    a = a- 2
print("abhi")
    
 
# 10 12 14
# Out:
# 10
# 12
# 14
# abhi

# %%
a = [10,25,33,45,66,88,99,100]
odd = [] # 25 33 45  99 
even = [] #10 66 88  100

for i in range(len(a)) : # for i in [0,1,2,3,4,5,6,7]
    if a[i] % 2 ==1 :
        odd.append(a[i])
    else :
        even.append(a[i])
print(odd,even)
# Out:
# [25, 33, 45, 99] [10, 66, 88, 100]

# %%
a = [10,25,33,45,66,88,99,100]
odd = [] # 25 33 45  99 

for i in range(len(a)) : # for i in [0,1,2,3,4,5,6,7]
    if a[i] % 2 ==1 :
        odd.append(a[i])
odd
# Out:
# [25, 33, 45, 99]

# %%
value 
init value  = []

loop cond 1
    cond 2
       append value to init value

# %%
init value = [appendvalue  loop1 loop 2     ...   ]

# %%
a = [10,25,33,45,66,88,99,100]
oddlist = [a[i] for i in range(len(a)) if a[i] % 2 ==1]
oddlist
# Out:
# [25, 33, 45, 99]

# %%
for i in range(8):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
a = [10,25,33,45,66,88,99,100]
odd = [] # 45  99 

for i in range(len(a)) : # for i in [0,1,2,3,4,5,6,7]
    if a[i] % 2 ==1 :
        if a[i] > 40     :
            odd.append(a[i])
odd
# Out:
# [45, 99]

# %%
a = [10,25,33,45,66,88,99,100]
odd1 = [a[i] for i in range(len(a)) if a[i] % 2 ==1 if a[i] > 40] # 25 33 45  99 
odd1
# Out:
# [45, 99]

# %%
mid1 = 30
mid2 = 50
# 45 45
if mid1 > 40 and mid2 > 40 :
    print("eligible")
else :
    print(" not Eligible for placemenst")

# %%
mid1 = 45
mid2 = 45
# 45 45
if mid1 > 40 and mid2 > 40 :
    print("eligible")
else :
    print(" not Eligible for placemenst")
# Out:
# eligible

# %%
mid1 = 42
mid2 = 42
# 45 45
if mid1 > 40 and mid2 > 40 :
    print("eligible")
else :
    print(" not Eligible for placemenst")
# Out:
# eligible

# %%
mid1 = int(input())
mid2 = int(input())
# 45 45
if mid1 > 40 and mid2 > 40 :
    print("eligible")
else :
    print(" not Eligible for placemenst")
# Out:
#  45
#  45
# eligible

# %%
def eligibility(mid1,mid2,name):
    print(name)
    if mid1 > 40 and mid2 > 40 :
        print("eligible")
    else :
        print(" not Eligible for placemenst")

# %%
eligibility(35,45,"abhi")
# Out:
# abhi
#  not Eligible for placemenst

# %%
eligibility(45,45,"dharthi")
# Out:
# dharthi
# eligible

# %%
a = 10
b = 20
c = a+b 
c
# Out:
# 30

# %%
def addition(a,b):
    c = a 
    print(c)

# %%
a = [1,2,3,4,5]
odd = []
for i in range(len(a)) : 
    if a[i] % 2 ==1 :
        odd.append(a[i])
odd
# Out:
# [1, 3, 5]

# %%
z = [20,45,555]
odd1 = []
for i in range(len(z)) : 
    if z[i] % 2 ==1 :
        odd1.append(z[i])
odd1
# Out:
# [45, 555]

# %%
def odtest(a,b = "student"):
    print(b)
    odd1 = []
    for i in range(len(a)) : 
        if a[i] % 2 ==1 :
            odd1.append(a[i])
    print(odd1)


odtest([20,45,60],"Abhi")
# Out:
# Abhi
# [45]

# %%
odtest([11,22,33],"dharthi")
# Out:
# dharthi
# [11, 33]

# %%
odtest([111,222,333])
# Out:
# student
# [111, 333]

# %%
def odtest(a,b = "student"):
    print(b)
    odd1 = []
    for i in range(len(a)) : 
        if a[i] % 2 ==1 :
            odd1.append(a[i])
    print(odd1)


odtest([20,45,60],"Abhi")
print("""mlv""")
# Out:
# Abhi
# [45]
# mlv

# %%
def odtest(a,b = "student"):
    print(b)
    odd1 = []
    for i in range(len(a)) : 
        if a[i] % 2 ==1 :
            odd1.append(a[i])
    return odd1


ans  = odtest([20,45,60],"Abhi") #odd1
print("""mlv""")
print(ans)
#if 1 > 0 :
 #   print(ans)
# Out:
# Abhi
# mlv
# [45]

# %%
def add(a,b) :
    c = a+b
    return c
ans = add(10,12)

# %%
if ans  > 20 :
    print(ans,"yes")
# Out:
# 22 yes

# %%
#lamda or anonymous function 


ans  = lambda a : "mlv" + str(a)
ans(22)
# Out:
# 'mlv22'

# %%
ans = lambda a,b : a+b

mid1 = int(input("enter mid1 value"))
mid2 = int(input("enter mid2 value"))
ans(mid1,mid2)
# Out:
# enter mid1 value 25
# enter mid2 value 35
# 60
